# %%
dir(pd.unique.__type_params__)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import missingno as msno
import plotly.express as px

from scipy import stats
import statsmodels.api as sm
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler, OneHotEncoder, PowerTransformer, OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split

# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = "walmart-sales-dataset-of-45stores.csv"

# Load the latest version
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "varsharam/walmart-sales-dataset-of-45stores",
  file_path,
  # Provide any additional arguments like
  # sql_query or pandas_kwargs. See the
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

print("First 5 records:", df.head())
# Out:
# /tmp/ipython-input-3081180906.py:10: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   df = kagglehub.load_dataset(
# Using Colab cache for faster access to the 'walmart-sales-dataset-of-45stores' dataset.
# First 5 records:    Store        Date  Weekly_Sales  ...  Fuel_Price         CPI  Unemployment
# 0      1  05-02-2010    1643690.90  ...       2.572  211.096358         8.106
# 1      1  12-02-2010    1641957.44  ...       2.548  211.242170         8.106
# 2      1  19-02-2010    1611968.17  ...       2.514  211.289143         8.106
# 3      1  26-02-2010    1409727.59  ...       2.561  211.319643         8.106
# 4      1  05-03-2010    1554806.68  ...       2.625  211.350143         8.106
#
# [5 rows x 8 columns]

# %%
df
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
df.shape
df.columns
df.head(5)
df.tail(4)
df.info()
df.dtypes
df.describe(include='all').T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB
#                count unique         top  ...         50%         75%         max
# Store         6435.0    NaN         NaN  ...        23.0        34.0        45.0
# Date            6435    143  05-02-2010  ...         NaN         NaN         NaN
# Weekly_Sales  6435.0    NaN         NaN  ...   960746.04  1420158.66  3818686.45
# ...

# %%
df1.columns
# Out:
# Index(['Store', 'Date', 'Weekly_Sales', 'Holiday_Flag', 'Temperature',
#        'Fuel_Price', 'CPI', 'Unemployment'],
#       dtype='object')

# %%
# boxplot
sns.boxplot(x=df['Weekly_Sales'])

# IQR rule
Q1 = df['Weekly_Sales'].quantile(0.25)
Q3 = df['Weekly_Sales'].quantile(0.75)
IQR = Q3 - Q1
outliers = df[(df['Weekly_Sales'] < Q1 - 1.5*IQR) | (df['Weekly_Sales'] > Q3 + 1.5*IQR)]

# z-score
df['zscore'] = np.abs(stats.zscore(df['Weekly_Sales'].dropna()))
df[df['zscore'] > 3]
# Out:
#       Store        Date  Weekly_Sales  ...         CPI  Unemployment    zscore
# 189       2  24-12-2010    3436007.68  ...  211.064660         8.163  4.233469
# 241       2  23-12-2011    3224369.80  ...  218.999550         7.441  3.858439
# 471       4  26-11-2010    2789469.45  ...  126.669267         7.127  3.087780
# 474       4  17-12-2010    2740057.14  ...  126.879484         7.127  3.000220
# 475       4  24-12-2010    3526713.39  ...  126.983581         7.127  4.394202
# 523       4  25-11-2011    3004702.33  ...  129.836400         5.143  3.469180
# 526       4  16-12-2011    2771397.17  ...  129.898065         5.143  3.055755
# 527       4  23-12-2011    3676388.98  ...  129.984548         5.143  4.659433
# 1329     10  26-11-2010    2939946.38  ...  126.669267         9.003  3.354430
# 1332     10  17-12-2010    2811646.85  ...  126.879484         9.003  3.127079
# 1333     10  24-12-2010    3749057.69  ...  126.983581         9.003  4.788204
# ...

# %%
# numeric
sns.histplot(df['Weekly_Sales'].dropna(), kde=True)
df['Weekly_Sales'].skew(), df['Weekly_Sales'].kurtosis()

'''# categorical
df['cat_col'].value_counts(normalize=True).head(10)
sns.countplot(y='cat_col', data=df, order=df['cat_col'].value_counts().index[:20])
'''
# Out:
# "# categorical\ndf['cat_col'].value_counts(normalize=True).head(10)\nsns.countplot(y='cat_col', data=df, order=df['cat_col'].value_counts().index[:20])\n"
